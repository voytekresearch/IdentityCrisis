# %% [markdown]
# ### Scraping abstract information
# March 4, 2018
# This notebook scrapes abstract text from:
# - Proceedings of the Annual Cognitive Science Society meeting archive (html)
# - Proceedings of Cognitive Neuroscience Society annual meeting (text converted from pdf)
#
# Abstracts are then stored in a spreadsheet, containing information such as year, authors, title, and abstract.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import csv
from bs4 import BeautifulSoup
import urllib
import re
import string
import pandas as pd
import os
import sys

# %%
def scrape_CS(home_url, data_file):
    #connect to home page url for that year
    CSurl = urllib.request.urlopen(home_url).read()
    soup = BeautifulSoup(CSurl, 'html.parser')
    all_links = soup.find_all('a', attrs={'href': re.compile("papers/*")})    
    year = home_url[-5:-1]    
    
    # enumerate through all paper links
    for link_idx, link in enumerate(all_links):
        # get soup from paper url
        if home_url not in str(link['href']):
            url_text = home_url + str(link['href'])
        else:
            url_text = str(link['href'])
    
        url = urllib.request.urlopen(url_text).read()
        soup = BeautifulSoup(url, 'html.parser')
    
        # scrape & parse
        authors = []
        affl = []
        title = ' '.join(soup.find_all('h1')[0].text.split())
        # exception rule for 2014 abstracts
        if '2014' in home_url:            
            abstr = ' '.join(soup.find_all('blockquote')[1].text.split())
        else:            
            abstr = ' '.join(soup.find_all('p', {"id": "abstract"})[0].text.split())            
        
        soup.find_all('ul')
        for ana in soup.find_all('em'):
            affl.append('>'+ana.text)
            if '2014' in home_url:
                # somebody fucked something up in 2014
                authors.append('>' + ana.previous_element.previous_element.split(',')[0])
            else:            
                authors.append('>' + ana.previous_element.split(',')[0])
        
        # do some gymnastics to get it into a pandas df and add as a row to CSV
        new_row = {'Year': str(year), 'Title': title,'Abstract': abstr,'Authors': ''.join(authors),'Affiliations': ''.join(affl), 'URL': url_text}
        df_cur = pd.Series(data=new_row).to_frame().T[['Year','Title','Abstract','Authors','Affiliations','URL']]
        df_cur.to_csv(data_file, mode='a', header=False, index=False)

# %%
# get all paper links from cogsci conference
home_urls = ['https://mindmodeling.org/cogsci2017/',
             'https://mindmodeling.org/cogsci2016/',
             'https://mindmodeling.org/cogsci2015/',
             'https://mindmodeling.org/cogsci2014/',
             'https://mindmodeling.org/cogsci2013/',
             'https://mindmodeling.org/cogsci2012/',
             'https://mindmodeling.org/cogsci2011/',
             'https://mindmodeling.org/cogsci2010/']

for year in home_urls:
    # scrape all
    print(year)
    scrape_CS(home_url=year, data_file='../data/cogsci_abstracts.csv')

# %% [markdown]
# ### gather CNS abstracts from text to csv

# %%
data_folder = '../data/CNS_programs/'
os.listdir(data_folder)
CNS_files = sorted([f for f in os.listdir(data_folder) if ('CNS' in f) and ('.txt' in f)])[:-1]
print(CNS_files)
# Out:
# ['CNS_2007_Program.txt', 'CNS_2008_Program.txt', 'CNS_2009_Program.txt', 'CNS_2010_Program.txt', 'CNS_2011_Program.txt', 'CNS_2012_Program.txt', 'CNS_2013_Program.txt', 'CNS_2014_Program.txt', 'CNS_2015_Program.txt', 'CNS_2016_Program.txt']

# %%
#col_names = ['CNS_file','start_sect','beg_ind','end_ind']

#reffering to the abs_list problem encountered in journal on 8/2/2018. I think this needs to be on the outside of the loop so that it can catch each abs_list year change


CNS_file=[]
start_sect=[]
beg_ind=[]
end_ind=[]

for i in range(len(CNS_files)):
    
    CNS_file.append(CNS_files[i])
    
    #print(CNS_files[i])
    file = open(data_folder+CNS_files[i], 'r')#the 8 is supposed to be "i" but I think that it is grabbing the last one and using that to make abs list each time 
    data = file.read()
    data_list = data.split('\n')
    abs_start = [ind for ind, d in enumerate(data_list) if '\x0cPoster Session A' in d][0]#tells you the ind where the first abstract is?
    
    start_sect.append([ind for ind, d in enumerate(data_list) if '\x0cPoster Session A' in d])
    #print([ind for ind, d in enumerate(data_list) if '\x0cPoster Session A' in d])
    
    abs_list = data_list[abs_start:]
    poster_beg_ind = next((ind for ind,s in enumerate(abs_list) if '\x0cPoster Session A' == s), None)    
    poster_end_ind = next((ind for ind,s in enumerate(abs_list) if '\x0cAuthor Index' == s), None)
    
    
    beg_ind.append(poster_beg_ind)
    
    end_ind.append(poster_end_ind)
    
    
    #print(poster_beg_ind, poster_end_ind)

# %%
cns_frame=pd.DataFrame({'CNS_file':CNS_file,'start_sect':start_sect,'beg_ind':beg_ind,'end_ind':end_ind})
cns_frame
# Out:
#                CNS_file  beg_ind  end_ind  \
# 0  CNS_2007_Program.txt        0    29493
# 1  CNS_2008_Program.txt        0    30363
# 2  CNS_2009_Program.txt        0    23882
# 3  CNS_2010_Program.txt        0    31628
# 4  CNS_2011_Program.txt        0    24580
# 5  CNS_2012_Program.txt        0    24793
# 6  CNS_2013_Program.txt        0    28381
# 7  CNS_2014_Program.txt        0    28084
# 8  CNS_2015_Program.txt        0    23909
# 9  CNS_2016_Program.txt        0    28305
#
#                                           start_sect
# 0                                             [1456]
# 1  [1538, 1748, 1969, 2189, 2414, 2647, 2884, 311...
# 2  [2181, 2395, 2613, 2834, 3076, 3310, 3545, 379...
# 3  [3236, 3472, 3718, 3974, 4229, 4460, 4694, 495...
# 4  [3326, 3420, 3667, 3907, 4148, 4394, 4628, 487...
# 5  [3516, 3610, 3848, 4113, 4353, 4587, 4836, 507...
# 6  [2881, 3128, 3372, 3626, 3852, 4106, 4348, 459...
# 7  [3137, 3250, 3505, 3753, 4009, 4253, 4493, 475...
# 8  [3350, 3588, 3829, 4068, 4322, 4566, 4823, 506...
# 9  [3593, 3823, 4072, 4313, 4566, 4827, 5087, 533...

# %%
#this cell specifically needs to be copied and pasted for every journal and needs to go first because all the rest of the cells use it to initialze abs_list
sect_abs=[]
abst=[]
title=[]
auth=[]
i=1
letter_start_ind = data_list.index('\x0cPoster Session A')
letter_end_ind = data_list.index('\x0cPoster Session B')
a_b_range= range(letter_start_ind,letter_end_ind)
a_b_range=list(a_b_range)
file = open(data_folder+CNS_files[8], 'r')# looks like this is the place where we call the specific year to parse
data = file.read()
data_list = data.split('\n')
abs_start = [ind for ind, d in enumerate(data_list) if '\x0cPoster Session A' in d][0]#tells you the ind where the first abstract is?
abs_list = data_list[abs_start:]
poster_beg_ind = data_list.index('\x0cPoster Session A')
#while cur_section = 'A':#dont know how this cur_section string being A will work. thinking 
    #better idea being from poster_beg_ind = data_list.index('\x0cPoster Session A') 
    #to poster_beg_ind = data_list.index('\x0cPoster Session B') make this a range
#['A' 'B']
#for cur_section in 
for i in range(len(a_b_range)):
    try:
        cur_section='A'
        cur_abs=i+1
        abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))

        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
    #     print(section_abst)
    #     print(cur_section+'%i'%(cur_abs+1))
    #     print(i, abs_beg_ind, abs_end_ind)
        start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs

        whole_abs=section_abst[start_abst:len(section_abst)]#the abstract separated from the title and author
        title_sect=section_abst[0:start_abst]#the title and author combined
        title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
        title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
        length_title_lst=' '.join(title_lst)
        auth_sect=section_abst[len(length_title_lst):start_abst]


        sect_abs.append(cur_section+'%i'%cur_abs)
        abst.append(whole_abs)
        title.append(length_title_lst)
        #auth.append(title_sect) old wrong way of getting author
        auth.append(auth_sect)
    except :
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-115eb3a8c3df> in <module>()
#      25         abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
# ---> 26         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))
#      27
#
# ValueError: 'A133' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-115eb3a8c3df> in <module>()
#      46         auth.append(auth_sect)
#      47     except :
# ---> 48         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
#      49         section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
#
# ValueError: 'A134' is not in list

# %%
i=1
letter_start_ind = data_list.index('\x0cPoster Session B')
letter_end_ind = data_list.index('\x0cPoster Session C')
a_b_range= range(letter_start_ind,letter_end_ind)
a_b_range=list(a_b_range)
file = open(data_folder+CNS_files[8], 'r')
data = file.read()
data_list = data.split('\n')
poster_beg_ind = data_list.index('\x0cPoster Session B')
#while cur_section = 'A':#dont know how this cur_section string being A will work. thinking 
    #better idea being from poster_beg_ind = data_list.index('\x0cPoster Session A') 
    #to poster_beg_ind = data_list.index('\x0cPoster Session B') make this a range
#['A' 'B']
#for cur_section in 
for i in range(len(a_b_range)):
    try:
        cur_section='B'
        cur_abs=i+1
        abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))

        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
    #     print(section_abst)
    #     print(cur_section+'%i'%(cur_abs+1))
    #     print(i, abs_beg_ind, abs_end_ind)
        start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs

        whole_abs=section_abst[start_abst:len(section_abst)]#the abstract separated from the title and author
        title_sect=section_abst[0:start_abst]#the title and author combined
        title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
        title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
        length_title_lst=' '.join(title_lst)
        auth_sect=section_abst[len(length_title_lst):start_abst]


        sect_abs.append(cur_section+'%i'%cur_abs)
        abst.append(whole_abs)
        title.append(length_title_lst)
        #auth.append(title_sect) old wrong way of getting author
        auth.append(auth_sect)
    except :
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-aa866f3998b4> in <module>()
#      19         abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
# ---> 20         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))
#      21
#
# ValueError: 'B133' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-aa866f3998b4> in <module>()
#      40         auth.append(auth_sect)
#      41     except :
# ---> 42         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
#      43         section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
#
# ValueError: 'B134' is not in list

# %%
i=1
letter_start_ind = data_list.index('\x0cPoster Session C')
letter_end_ind = data_list.index('\x0cPoster Session D')
a_b_range= range(letter_start_ind,letter_end_ind)
a_b_range=list(a_b_range)
file = open(data_folder+CNS_files[8], 'r')
data = file.read()
data_list = data.split('\n')
poster_beg_ind = data_list.index('\x0cPoster Session C')
#while cur_section = 'A':#dont know how this cur_section string being A will work. thinking 
    #better idea being from poster_beg_ind = data_list.index('\x0cPoster Session A') 
    #to poster_beg_ind = data_list.index('\x0cPoster Session B') make this a range
#['A' 'B']
#for cur_section in 
for i in range(len(a_b_range)):
    try:
        cur_section='C'
        cur_abs=i+1
        abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))

        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
    #     print(section_abst)
    #     print(cur_section+'%i'%(cur_abs+1))
    #     print(i, abs_beg_ind, abs_end_ind)
        start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs

        whole_abs=section_abst[start_abst:len(section_abst)]#the abstract separated from the title and author
        title_sect=section_abst[0:start_abst]#the title and author combined
        title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
        title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
        length_title_lst=' '.join(title_lst)
        auth_sect=section_abst[len(length_title_lst):start_abst]


        sect_abs.append(cur_section+'%i'%cur_abs)
        abst.append(whole_abs)
        title.append(length_title_lst)
        #auth.append(title_sect) old wrong way of getting author
        auth.append(auth_sect)
    except :
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-2bed5bf9afdc> in <module>()
#      19         abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
# ---> 20         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))
#      21
#
# ValueError: 'C133' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-2bed5bf9afdc> in <module>()
#      40         auth.append(auth_sect)
#      41     except :
# ---> 42         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
#      43         section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
#
# ValueError: 'C134' is not in list

# %%
i=1
letter_start_ind = data_list.index('\x0cPoster Session D')
letter_end_ind = data_list.index('\x0cPoster Session E')
a_b_range= range(letter_start_ind,letter_end_ind)
a_b_range=list(a_b_range)
file = open(data_folder+CNS_files[8], 'r')
data = file.read()
data_list = data.split('\n')
poster_beg_ind = data_list.index('\x0cPoster Session D')
#while cur_section = 'A':#dont know how this cur_section string being A will work. thinking 
    #better idea being from poster_beg_ind = data_list.index('\x0cPoster Session A') 
    #to poster_beg_ind = data_list.index('\x0cPoster Session B') make this a range
#['A' 'B']
#for cur_section in 
for i in range(len(a_b_range)):
    try:
        cur_section='D'
        cur_abs=i+1
        abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))

        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
    #     print(section_abst)
    #     print(cur_section+'%i'%(cur_abs+1))
    #     print(i, abs_beg_ind, abs_end_ind)
        start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs

        whole_abs=section_abst[start_abst:len(section_abst)]#the abstract separated from the title and author
        title_sect=section_abst[0:start_abst]#the title and author combined
        title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
        title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
        length_title_lst=' '.join(title_lst)
        auth_sect=section_abst[len(length_title_lst):start_abst]


        sect_abs.append(cur_section+'%i'%cur_abs)
        abst.append(whole_abs)
        title.append(length_title_lst)
        #auth.append(title_sect) old wrong way of getting author
        auth.append(auth_sect)
    except :
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4361437388c8> in <module>()
#      19         abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
# ---> 20         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))
#      21
#
# ValueError: 'D134' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4361437388c8> in <module>()
#      40         auth.append(auth_sect)
#      41     except :
# ---> 42         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
#      43         section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
#
# ValueError: 'D135' is not in list

# %%
i=1
letter_start_ind = data_list.index('\x0cPoster Session E')
letter_end_ind = data_list.index('\x0cPoster Session F')
a_b_range= range(letter_start_ind,letter_end_ind)
a_b_range=list(a_b_range)
file = open(data_folder+CNS_files[8], 'r')
data = file.read()
data_list = data.split('\n')
poster_beg_ind = data_list.index('\x0cPoster Session E')
#while cur_section = 'A':#dont know how this cur_section string being A will work. thinking 
    #better idea being from poster_beg_ind = data_list.index('\x0cPoster Session A') 
    #to poster_beg_ind = data_list.index('\x0cPoster Session B') make this a range
#['A' 'B']
#for cur_section in 
for i in range(len(a_b_range)):
    try:
        cur_section='E'
        cur_abs=i+1
        abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))

        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
    #     print(section_abst)
    #     print(cur_section+'%i'%(cur_abs+1))
    #     print(i, abs_beg_ind, abs_end_ind)
        start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs

        whole_abs=section_abst[start_abst:len(section_abst)]#the abstract separated from the title and author
        title_sect=section_abst[0:start_abst]#the title and author combined
        title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
        title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
        length_title_lst=' '.join(title_lst)
        auth_sect=section_abst[len(length_title_lst):start_abst]


        sect_abs.append(cur_section+'%i'%cur_abs)
        abst.append(whole_abs)
        title.append(length_title_lst)
        #auth.append(title_sect) old wrong way of getting author
        auth.append(auth_sect)
    except :
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-7b5a69ff8500> in <module>()
#      19         abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
# ---> 20         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))
#      21
#
# ValueError: 'E134' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-7b5a69ff8500> in <module>()
#      40         auth.append(auth_sect)
#      41     except :
# ---> 42         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
#      43         section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
#
# ValueError: 'E135' is not in list

# %%
i=1
letter_start_ind = data_list.index('\x0cPoster Session F')
letter_end_ind = data_list.index('\x0cPoster Topic Index')
a_b_range= range(letter_start_ind,letter_end_ind)
a_b_range=list(a_b_range)
file = open(data_folder+CNS_files[8], 'r')
data = file.read()
data_list = data.split('\n')
poster_beg_ind = data_list.index('\x0cPoster Session F')
#while cur_section = 'A':#dont know how this cur_section string being A will work. thinking 
    #better idea being from poster_beg_ind = data_list.index('\x0cPoster Session A') 
    #to poster_beg_ind = data_list.index('\x0cPoster Session B') make this a range
#['A' 'B']
#for cur_section in 
for i in range(len(a_b_range)):
    try:
        cur_section='F'
        cur_abs=i+1
        abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))

        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
    #     print(section_abst)
    #     print(cur_section+'%i'%(cur_abs+1))
    #     print(i, abs_beg_ind, abs_end_ind)
        start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs

        whole_abs=section_abst[start_abst:len(section_abst)]#the abstract separated from the title and author
        title_sect=section_abst[0:start_abst]#the title and author combined
        title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
        title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
        length_title_lst=' '.join(title_lst)
        auth_sect=section_abst[len(length_title_lst):start_abst]


        sect_abs.append(cur_section+'%i'%cur_abs)
        abst.append(whole_abs)
        title.append(length_title_lst)
        #auth.append(title_sect) old wrong way of getting author
        auth.append(auth_sect)
    except :
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3c2cd223529f> in <module>()
#      19         abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
# ---> 20         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))
#      21
#
# ValueError: 'F130' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3c2cd223529f> in <module>()
#      40         auth.append(auth_sect)
#      41     except :
# ---> 42         abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
#      43         section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract
#
# ValueError: 'F131' is not in list

# %%
#making a datatable to see how the data fills the table which will help better understand the format i need to put the data into
try_table=pd.DataFrame({'sect_abs':sect_abs,'abst':abst,'title':title,'auth':auth})

# %%
try_table
# Out:
#                                                   abst  \
# 0     — Navigating our complex  auditory world requ...
# 1     — Selective attention modulates the P1-N1-P2 ...
# 2     — Crowded  acoustic environments pose a diffi...
# 3     — Selective attention is known to facilitate ...
# 4     — When attention is directed to particular ob...
# 5     — Auditory attention is crucial to the abilit...
# 6     — Salient  peripheral sounds trigger a contra...
# 7     — Inhibition of return means delayed response...
# 8     — Object-based attention studies have shown t...
# 9     — Research on visual neglect has typically fo...
# 10    — Although migraine is traditionally categori...
# 11    — Neuroimaging and  2  lesions studies indica...
# 12    — Attentional  deficits are common in reading...
# 13    — Autism spectrum disorder (ASD) is known to ...
# 14    — Williams Syndrome (WS) is a genetic disorde...
# 15    — Socioeconomic status (SES) is well-es-  tab...
# 16    — Chronic, perceived stress has been linked w...
# 17    — Hexanucleotide repeat expansion in C9orf72 ...
# 18    — Neuroimaging and electrophysiological metho...
# 19    — People with autism spectrum disorders (ASD)...
# 20    — Face perception and face recognition are cr...
# 21    — Social life involves learning about others ...
# 22    — Previous evidence demonstrates that social ...
# 23    — Social cognition is a fundamental behaviour...
# 24    — Neuroimaging studies have consistently impl...
# 25    — The region of the brain most consistently a...
# 26    — People are intrinsically motivated  to purs...
# 27    — How does self-relevance via ownership affec...
# 28    — The neural basis of love  has gradually bee...
# 29    — Factor analysis is a driving influence  in ...
# ..                                                 ...
# 733   — INTRODUCTION: Increasing contextual interfe...
# 734   — Results from animal studies suggest  fronta...
# 735   — The brain has a remarkable abil-  ity to ad...
# 736   — Sonification refers to a process by which d...
# 737   — Correct recog-  nition of individual sound ...
# 738   — Past studies have shown that activity in sp...
# 739   — When speech is interrupted by intermittent ...
# 740   — In music, a motif often repeats in differen...
# 741   — Tracking pitch and beat are important objec...
# 742   — The neural dynamics underlying audiomotor l...
# 743   — Individuals often fail to notice changes to...
# 744   — This study investigates the time-course of ...
# 745   — One of the first steps to learning to read ...
# 746   —  Previous audiovisual Stroop studies used s...
# 747   — There is  growing evidence to suggest that ...
# 748   — Adults do not usually see  colors and shape...
# 749   — Video gaming as a pastime has increased rap...
# 750   — Cognitive embodiment refers to idea that co...
# 751   — The early right anterior negativity (ERAN),...
# 752   — The ventral  intraparietal area (VIP) both ...
# 753   — Dissociation is a multifaceted con-  struct...
# 754   — Multiple studies of mathematical fact retri...
# 755   — Creativity is a driving force for innovatio...
# 756   — Graph theory provides a fruitful  framework...
# 757   — We  recently found that the human brain’s f...
# 758   — Frontal midline theta (FMT) consists of 4-7...
# 759   — The ability to perform symbolic math  depen...
# 760   — While there is evidence of sex  differences...
# 761   — Inter-  est in mindfulness has grown in the...
# 762   — Both children and adults experience pervasi...
#
#                                                   auth sect_abs  \
# 0    sa L. Gamble1, Marty G. Woldorff1; 1Duke Unive...       A1
# 1     Monica Wagner1, Valerie Shafer2, Mitchell Ste...       A2
# 2     Dillon Hambrook1,2, Matthew Tata1,2; 1Univers...       A3
# 3     Sung-Joo Lim1, Jöran Lepsien1, Malte Wöstmann...       A4
# 4    e Wöstmann1,2, Björn Herrmann1, Burkhard Maess...       A5
# 5     Lisa Payne1, Chad Rogers2, Sujala Maharjan1, ...       A6
# 6    ld1, Alannah T. Wallace1, Ashley C. Livingston...       A7
# 7     Edmund Wascher1, Sven Hoffmann2, Daniel Schne...       A8
# 8     Jane Couperus1,2, Colin Quirk1; 1Cognitive Sc...       A9
# 9    ancesca Fortenbaugh1,2,3, Krista Schendel1, Ly...      A10
# 10   m1, Marla J. S. Mickleborough2, Chelsea Eades1...      A11
# 11   as Bedo1, Sam M. Doesburg2,3, Lawrence M. Ward...      A12
# 12    Jessica Green1, William Brixius1, Kristina Dr...      A13
# 13    Masahiro Kawasaki1, Hidetsugu Komeda2, Toshiy...      A14
# 14   ilip Lai1,2,3, Talent V. Dang1, Ursula Bellugi...      A15
# 15    Katherine Swett1, Yuankai Huo1, Elyce William...      A18
# 16   sta Watson1, Nihar Patel1, Matthew Wynn1, Joel...      A19
# 17   M Khazenzon1, Andrew J Trujillo1, Christine C ...      A20
# 18         Jie Yuan1, Shimin Fu1; 1Tsinghua University      A21
# 19    Pantelis1, Lisa Byrge1, J. Michael Tyszka2, R...      A22
# 20    Claudia Schulz1, Julian Hagemann1, Thomas Str...      A23
# 21   Hackel1, Bradley B. Doll1, David M. Amodio1; 1...      A24
# 22   andon Levy1, Chris I. Baker1; 1Laboratory of B...      A25
# 23   lin Hawco1, Natasa Kovacevic2, Anil Malhotra3,...      A26
# 24    Carissa Philippi1, Maia Pujara1, Conrad Gudmu...      A27
# 25   C. Fields1,2, Kirsten Weber3,2, Ben Stillerman...      A28
# 26    Zhenhao Shi1, Yuqing Zhou2, Shihui Han2; 1Uni...      A29
# 27    Grace Truong1, Kevin Roberts1, Cassie Cowie1,...      A30
# 28    Ryuhei Ueda1, Hiroshi Ashida1, Nobuhito Abe2;...      A31
# 29   ura Feren1, Kenneth Davis2; 1Brandman Universi...      A32
# ..                                                 ...      ...
# 733  Ching Yang1, Chien-Ho Janice Lin1,2, Allan D W...      F99
# 734   Kyle Morgan1,2, Phan Luu2, Nicholas Price2, D...     F100
# 735   Laureline Arnaud1,2, Lucie Ménard2,3, Vincent...     F101
# 736   Matan Koplin-Green1, Michael Massone1, Mark F...     F102
# 737  De Meo1,2, Pawel J. Mastusz1,2, Jean-François ...     F103
# 738  el Kennedy-Higgins1, John Hogan2, Joseph Devli...     F104
# 739  a Soni1, Dillon A. Hambrook1, Matthew S. Tata1...     F105
# 740   Madeline Huberth1, Takako Fujioka1; 1Stanford...     F106
# 741  riel A Nespoli1, Paolo Ammirante1, Frank A Rus...     F107
# 742   Alexander Herman1, Damien Harrell2, Megan Tho...     F108
# 743  so1, Daniel M. Roberts, George A. Buzzell, Cra...     F109
# 744   Orestis Papaioannou1, Julia Strand2, Christia...     F110
# 745   Osamu Takai1, Anthony Herdman1; 1University o...     F111
# 746   Ido Bornstein1, Anthony Herdman1; 1University...     F112
# 747   Katie Groves1, Steffan Kennett2, Helge Gillme...     F113
# 748   Leah Sanson1, Ferrinne Spector2; 1Edgewood Co...     F114
# 749   Johan Mårtensson1,3, Jürgen Gallinat2, Ulman ...     F115
# 750   Chelsea Ekstrand1, Eric Lorentz1, Layla Gould...     F116
# 751   Hana Shin1, Takako Fujioka1; 1 Stanford Unive...     F117
# 752   Andrea Serino1, Manuela Ansaldo2,3, Gaspare G...     F118
# 753   Matthew Jerram1, Alyson Negreira1; 1Suffolk U...     F119
# 754   FACTS Danielle S. Dickson1, Kara D. Federmeie...     F120
# 755  ilee R. Naylor1,2, Marjorie Taylor1; 1Universi...     F121
# 756  rsten Hilger1,2, Matthias Ekman3, Christian J....     F122
# 757   Doug Schultz1, Michael Cole1; 1Rutgers Univer...     F123
# 758   John Treffalls1, Brian Fremaux1, Hannah Wojci...     F124
# 759  ipra Kanjlia1, Connor T. Lane1, Lisa Feigenson...     F125
# 760  ei1, Philip Kohn1, J. Shane Kippenhan1, Bhaska...     F126
# 761   Gina Falcone1, Matthew Jerram1; 1Suffolk Univ...     F127
# 762   Mark Lewis1,2, Elizabeth Toomarian2, Edward H...     F128
#
#                                                  title
# 0     A1 SEARCHING FOR MULTIPLE AUDITORY TARGETS L. G.
# 1    A2 THE EFFECT OF ATTENTION ON CORTICAL SENSORY...
# 2    A3 TWO’S COMPANY, BUT MORE’S A PARTY: THETA-BA...
# 3    A4 SELECTIVE ATTENTION TO MEMORY REPRESENTATIO...
# 4    A5 LATERALIZED ALPHA OSCILLATIONS REFLECT ATTE...
# 5    A6 OLDER AND YOUNGER ADULTS CAN REDUCE THE COC...
# 6    A7 SALIENT SOUNDS ACTIVATE VISUAL CORTEX: DISE...
# 7    A8 RESPONSE SELECTION DOES NOT CONTRIBUTE TO I...
# 8    A9 FACILITATION AND SUPPRESSION IN OBJECT BASE...
# 9    A10 THE NEGLECTED LEFT HEMISPHERE: CHRONIC RIG...
# 10   A11 MIGRAINEURS AND THEIR ATTENTION TO VISUAL ...
# 11   A12 TOP-DOWN INFORMATION FLOW IN AN ALPHA OSCI...
# 12   A13 NEURAL CORRELATES OF VOLUNTARY VISUOSPATIA...
# 13   A14 MENTAL ROTATION FOR ASD AND PERSPECTIVE TA...
# 14   A15 THE RELATIONSHIP BETWEEN GESTURES AND LANG...
# 15   A18 SOCIOECONOMIC STATUS PREDICTS PREFRONTAL C...
# 16   A19 PERCEIVED STRESS AND UNCINATE WHITE MATTER...
# 17   A20 ALTERED NETWORK CONNECTIVITY IN FRONTOTEMP...
# 18   A21 THE ELECTROPHYSIOLOGICAL CORRELATES OF UNC...
# 19   A22 SPECIFIC HYPOACTIVATION OF RIGHT TEMPORO-P...
# 20   A23 ELECTROPHYSIOLOGICAL CORRELATES OF EMOTION...
# 21   A24 NEURAL SIGNATURES OF BOTH TRAIT AND VALUE ...
# 22   A25 EXTRAPOLATION OF SOCIAL INFORMATION TO PHY...
# 23   A26 ACTIVATION DURING A FACIAL EMOTION OBSERVE...
# 24   A27 DISTINCT STRUCTURAL BRAIN CORRELATES OF SE...
# 25   A28 EMOTIONAL VALENCE MODULATES SELF VS. OTHER...
# 26   A29 THE NEURAL SUBSTRATES OF INDIVIDUAL AND CO...
# 27   A30 I SAW MINE FIRST: SELF-RELEVANCE AS OWNERS...
# 28   A31 NEURAL BASIS OF INHIBITING SOCIALLY UNACCE...
# 29   A32 REFINING A NEUROSCIENCE APPROACH TO PERSON...
# ..                                                 ...
# 733  F99 STRENGTHENED BRAIN FUNCTIONAL CONNECTIVITY...
# 734  F100 INVESTIGATING THE NEURAL CORRELATES OF EX...
# 735  F101 MUSICAL BEAT PERCEPTION AND PRODUCTION IN...
# 736  F102 RAPIDLY-LEARNED IDENTIFICATION OF SEIZURE...
# 737  F103 LIMITATIONS IN FINE-GRAINED WITHIN-CATEGO...
# 738  F104 MOTOR REPRESENTATIONS OF SPEECH SPECIFICA...
# 739  F105 THETA-BAND PHASE TRACKING IN INTERRUPTED ...
# 740  F106 ENCODING POLYPHONIC MUSICAL MOTIVES: EFFE...
# 741  F107 NEURONAL ENTRAINMENT TO AUDITORY STIMULI ...
# 742  F108 NEURAL DYNAMICS OF NOVEL AUDITORY-MOTOR M...
# 743  F109 ELECTROPHYSIOLOGICAL EVIDENCE FOR FACILIT...
# 744  F110 MULTISTAGE AUDIOVISUAL SPEECH PROCESSING ...
# 745  F111 FUNCTIONAL CONNECTIVITY OF LETTER-SOUND P...
# 746  F112 AUDIOVISUAL COLOUR-WORD STROOP MATCHING T...
# 747  F113 INVESTIGATING BODY PERCEPTION IN HEALTHY ...
# 748  F114 THE SHAPE AND COLOR OF MUSIC: NATURALLY B...
# 749  F115 WHITE MATTER INTEGRITY IN VISUAL, MOTOR A...
# 750  F116 HAPTIC PRIMING IN EMBODIED COGNITION: SOM...
# 751  F117 VISUAL PREDICTIVE INFORMATION MODULATES M...
# 752  F118 THE SPACE AROUND YOU. VENTRAL INTRAPARIET...
# 753  F119 STRUCTURAL MRI IN DEFAULT MODE NETWORK RE...
# 754  F120 X EVENT-RELATED POTENTIALS REVEAL HEMISPH...
# 755  F121 DIFFERENTIAL EFFECTS OF GLOBAL AND LOCAL ...
# 756  F122 NETWORK CENTRALITY IN PREFRONTAL CORTEX I...
# 757  F123 TASK-GENERAL AND TASK-SPECIFYING FUNCTION...
# 758  F124 MODULATION OF FRONTAL MIDLINE THETA DURIN...
# 759  F125 NUMERICAL ABILITIES DEVELOP INDEPENDENT O...
# 760  F126 INTERACTION BETWEEN BRAIN-DERIVED NEUROTR...
# 761  F127 BECOMING CENTERED: META-ANALYSIS OF FMRI ...
# 762  F128 REPRESENTATION OF SYMBOLIC FRACTIONS RECR...
#
# [763 rows x 4 columns]

# %%
172+172+173+176+171+175

# %% [markdown]
# Testing another year

# %%
sect_abs1=[]
abst1=[]
title1=[]
auth1=[]
i=1

file = open(data_folder+CNS_files[8], 'r')# looks like this is the place where we call the specific year to parse
data = file.read()
data_list = data.split('\n')
letter_start_ind = data_list.index('\x0cPoster Session A')
letter_end_ind = data_list.index('\x0cPoster Session B')
a_b_range= range(letter_start_ind,letter_end_ind)
a_b_range=list(a_b_range)
poster_beg_ind = data_list.index('\x0cPoster Session A')
#while cur_section = 'A':#dont know how this cur_section string being A will work. thinking 
    #better idea being from poster_beg_ind = data_list.index('\x0cPoster Session A') 
    #to poster_beg_ind = data_list.index('\x0cPoster Session B') make this a range
#['A' 'B']
#for cur_section in 
for i in range(len(a_b_range)):
    try:
        cur_section='A'
        cur_abs=i+1
        abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))

        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
    #     print(section_abst)
    #     print(cur_section+'%i'%(cur_abs+1))
    #     print(i, abs_beg_ind, abs_end_ind)
        start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs

        whole_abs=section_abst[start_abst:len(section_abst)]#the abstract separated from the title and author
        title_sect=section_abst[0:start_abst]#the title and author combined
        title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
        title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
        length_title_lst=' '.join(title_lst)
        auth_sect=section_abst[len(length_title_lst):start_abst]


        sect_abs1.append(cur_section+'%i'%cur_abs)
        abst1.append(whole_abs)
        title1.append(length_title_lst)
        #auth.append(title_sect) old wrong way of getting author
        auth1.append(auth_sect)
    except :
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract

# %%
data_list

# %%
#making a datatable to see how the data fills the table which will help better understand the format i need to put the data into
try_table_2015=pd.DataFrame({'sect_abs1':sect_abs1,'abst1':abst1,'title1':title1,'auth1':auth1})

# %%
try_table_2015

# %%
#this cell is the bare bones for how the function will run

#AKA test weird cases in here bc you can input the specific abstract you want

# d = {'sect_abs':[],'abs':[],'title':[],'auth':[]}
# Df_2016=pd.DataFrame(data=d)

# for i in range(len())
cur_section = 'A'
#cur_section = 'E '
cur_abs = 5
abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))

start_string=cur_section+'%i'%cur_abs 

section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
start_abst=section_abst.index(" — ")#index with in the section where we first see this character - which denotes start of abs
whole_abs=section_abst[start_abst+3:len(section_abst)]#the abstract separated from the title and author
title_sect=section_abst[0:start_abst]#the title and author combined
title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words

length_title_lst=' '.join(title_lst)
remove_start_string=length_title_lst.replace(start_string,"")
auth_sect=section_abst[len(remove_start_string):start_abst]

strings=cur_section+'%i'%cur_abs

length_title_lst=' '.join(title_lst)



# Df_2016.sect_abs.append(cur_section)
# Df_2016.abs.append(whole_abs)
# Df_2016.title.append(title_lst)
# Df_2016.auth.append(title_sect)
#WIP=[word for word in title_sect if not word.islower() and not word.isupper()]#this could possibly be a filter however I intended it to give me mixed case strings which would be the authors.
#WIP

# %%
remove_start_string
# Out:
# ' LATERALIZED ALPHA OSCILLATIONS REFLECT ATTENTIONAL SELECTION OF SPEECH IN NOISE 3MEG'

# %% [markdown]
# Notes for table
# -abst seems fine
#
# -auth
#     want to take out the A# and lowercase it and only include the actual author
#
# -sect_abs
#     want to add number to the A
#
# -title
#     want to join and then lower and drop the A#

# %%
sect_abs=[]
abst=[]
title=[]
auth=[]
i=1
letter_start_ind = data_list.index('\x0cPoster Session A')
letter_end_ind = data_list.index('\x0cPoster Session B')
a_b_range= range(letter_start_ind,letter_end_ind)
a_b_range=list(a_b_range)
file = open(data_folder+CNS_files[9], 'r')
data = file.read()
data_list = data.split('\n')
poster_beg_ind = data_list.index('\x0cPoster Session A')
#while cur_section = 'A':#dont know how this cur_section string being A will work. thinking 
    #better idea being from poster_beg_ind = data_list.index('\x0cPoster Session A') 
    #to poster_beg_ind = data_list.index('\x0cPoster Session B') make this a range
#['A' 'B']
#for cur_section in 
for i in range(len(a_b_range)):
    try:
        cur_section='A'
        cur_abs=i+1
        abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))

        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
    #     print(section_abst)
    #     print(cur_section+'%i'%(cur_abs+1))
    #     print(i, abs_beg_ind, abs_end_ind)
        start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs

        whole_abs=section_abst[start_abst:len(section_abst)]#the abstract separated from the title and author
        title_sect=section_abst[0:start_abst]#the title and author combined
        title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
        title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
        length_title_lst=' '.join(title_lst)
        auth_sect=section_abst[len(length_title_lst):start_abst]


        sect_abs.append(cur_section+'%i'%cur_abs)
        abst.append(whole_abs)
        title.append(length_title_lst)
        #auth.append(title_sect) old wrong way of getting author
        auth.append(auth_sect)
    except :
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract

# %% [markdown]
# Playing with try and except.
#
# gonna see if i can try some ids B144 and if not there except B145 and then if not there try C1

# %% [markdown]
# This works! check line 21! okay so now we need it to work where it trys C1 after the Bs fail
#
# wait no since this works we can just run all the cells like this one and we should get most of the data and then when we show the code to richard he can help run it more efficently but i want to at least get him some data

# %%
i=1
letter_start_ind = data_list.index('\x0cPoster Session B')
letter_end_ind = data_list.index('\x0cPoster Session C')
a_b_range= range(letter_start_ind,letter_end_ind)
a_b_range=list(a_b_range)
file = open(data_folder+CNS_files[9], 'r')
data = file.read()
data_list = data.split('\n')
poster_beg_ind = data_list.index('\x0cPoster Session B')
#while cur_section = 'A':#dont know how this cur_section string being A will work. thinking 
    #better idea being from poster_beg_ind = data_list.index('\x0cPoster Session A') 
    #to poster_beg_ind = data_list.index('\x0cPoster Session B') make this a range
#['A' 'B']
#for cur_section in 
for i in range(len(a_b_range)):
    try:
        cur_section='B'
        cur_abs=i+1
        abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))
    except:
        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+2)) #works!!
        #add_one(cur_abs) was playing with functions this works i think but would rather use line above
        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
#     print(section_abst)
#     print(cur_section+'%i'%(cur_abs+1))
#     print(i, abs_beg_ind, abs_end_ind) 
        try:
            start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs

            whole_abs=section_abst[start_abst:len(section_abst)]#the abstract separated from the title and author
            title_sect=section_abst[0:start_abst]#the title and author combined
            title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
            title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
            length_title_lst=' '.join(title_lst)
            auth_sect=section_abst[len(length_title_lst):start_abst]


            sect_abs.append(cur_section+'%i'%cur_abs)
            abst.append(whole_abs)
            title.append(length_title_lst)
            #auth.append(title_sect) old wrong way of getting author
            auth.append(auth_sect)
        except :
            print(cur_section+'%i'%(cur_abs))

# %%
#making a datatable to see how the data fills the table which will help better understand the format i need to put the data into
try_table=pd.DataFrame({'sect_abs':sect_abs,'abst':abst,'title':title,'auth':auth})

try_table

# %% [markdown]
# an example i saw leads me to believe that you can make a function for cases you want to except and then fix these things within the function?
#
# lets try?

# %%
#this cell specifically needs to be copied and pasted for every journal and needs to go first because all the rest of the cells use it to initialze abs_list
sect_abs=[]
abst=[]
title=[]
auth=[]
CNS_Year=[]

let_vec = ['A','B','C','D','E','F','G','H','I']
for x in range(len(CNS_files)):
#     letter_start_ind = data_list.index('\x0cPoster Session A')
#     letter_end_ind = data_list.index('\x0cPoster Session B')
#     a_b_range= range(letter_start_ind,letter_end_ind)
#     a_b_range=list(a_b_range)
    
    file = open(data_folder+CNS_files[x], 'r')# looks like this is the place where we call the specific year to parse
    data = file.read()
    data_list = data.split('\n')
    abs_start = [ind for ind, d in enumerate(data_list) if '\x0cPoster Session A' in d][0]#tells you the ind where the first abstract is?
    abs_list = data_list[abs_start:]
    poster_beg_ind = data_list.index('\x0cPoster Session A')

    



    for j in range(0,len(let_vec)):

        print(j)

        for i in range(0,200):

            try:
                cur_section= let_vec[j]
                cur_abs=i
                abs_beg_ind = abs_list.index(cur_section+'%i'%cur_abs)
                abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+1))
                last_index = cur_section+'%i'%(cur_abs+1)
                print(cur_abs)

                section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
                #     print(section_abst)
                #     print(cur_section+'%i'%(cur_abs+1))
                #     print(i, abs_beg_ind, abs_end_ind)
                start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs
                start_string=cur_section+'%i'%cur_abs #the F4 like number at the beg of each title that isnt needed

                whole_abs=section_abst[start_abst+3:len(section_abst)]#the abstract separated from the title and author
                title_sect=section_abst[0:start_abst]#the title and author combined
                title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
                title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
                length_title_lst=' '.join(title_lst)
                remove_start_string=length_title_lst.replace(start_string,"")
                auth_sect=section_abst[len(length_title_lst):start_abst]



                sect_abs.append(cur_section+'%i'%cur_abs)
                abst.append(whole_abs)
                title.append(remove_start_string)
                #auth.append(title_sect) old wrong way of getting author
                auth.append(auth_sect)
                CNS_Year.append(CNS_file[x])


                last_good = i
            except ValueError:

                for k in range(2,51):
                    try:
                        #print('k = ',k)
                        #print(cur_section+'%i'%(cur_abs+k))
                        abs_end_ind = abs_list.index(cur_section+'%i'%(cur_abs+k))

                        section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
                        #     print(section_abst)
                        #     print(cur_section+'%i'%(cur_abs+1))
                        #     print(i, abs_beg_ind, abs_end_ind)
                        start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs
                        start_string=cur_section+'%i'%cur_abs #the F4 like number at the beg of each title that isnt needed

                        whole_abs=section_abst[start_abst+3:len(section_abst)]#the abstract separated from the title and author
                        title_sect=section_abst[0:start_abst]#the title and author combined
                        title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
                        title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
                        length_title_lst=' '.join(title_lst)
                        remove_start_string=length_title_lst.replace(start_string,"")
                        auth_sect=section_abst[len(length_title_lst):start_abst]


                        sect_abs.append(cur_section+'%i'%cur_abs)
                        abst.append(whole_abs)
                        title.append(remove_start_string)
                        #auth.append(title_sect) old wrong way of getting author
                        auth.append(auth_sect)
                        CNS_Year.append(CNS_file[x])


                        break
                    except:
                        #print('except')
                        pass


                    else:
                        #print('reached else')
                        pass

                #print('last index =',last_index)



    #                 except ValueError:
    #                             abs_beg_ind = abs_list.index(last_index)
    #                             #nxt = cur_section + 1
    #                             abs_end_ind = abs_list.index('B'+'%i'%z)

    #                             section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
    #                             #     print(section_abst)
    #                             #     print(cur_section+'%i'%(cur_abs+1))
    #                             #     print(i, abs_beg_ind, abs_end_ind)
    #                             start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs
    #                             start_string=last_index #the F4 like number at the beg of each title that isnt needed

    #                             whole_abs=section_abst[start_abst+3:len(section_abst)]#the abstract separated from the title and author
    #                             title_sect=section_abst[0:start_abst]#the title and author combined
    #                             title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
    #                             title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
    #                             length_title_lst=' '.join(title_lst)
    #                             remove_start_string=length_title_lst.replace(start_string,"")
    #                             auth_sect=section_abst[len(length_title_lst):start_abst]


    #                             sect_abs.append(cur_section+'%i'%cur_abs)
    #                             abst.append(whole_abs)
    #                             title.append(remove_start_string)
    #                             #auth.append(title_sect) old wrong way of getting author
    #                             auth.append(auth_sect)
    #                             last_index
    #                     # letter + last index up to B1 
    #                     # section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract

    #                             pass
            except:

                                abs_beg_ind = abs_list.index(last_index)
                                nxt = cur_section + 1
                                abs_end_ind = abs_list.index(let_vec[j+1]+'%i'%nxt)

                                section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract 
                                #     print(section_abst)
                                #     print(cur_section+'%i'%(cur_abs+1))
                                #     print(i, abs_beg_ind, abs_end_ind)
                                start_abst=section_abst.index(' — ')#index with in the section where we first see this character - which denotes start of abs
                                start_string=last_index #the F4 like number at the beg of each title that isnt needed

                                whole_abs=section_abst[start_abst+3:len(section_abst)]#the abstract separated from the title and author
                                title_sect=section_abst[0:start_abst]#the title and author combined
                                title_auth_lst=title_sect.split(' ')#splits them up into list items so that the lamdas will work? have not tried to run without this
                                title_lst=[word for word in title_auth_lst if word.isupper()]#takes only all uppercase words
                                length_title_lst=' '.join(title_lst)
                                remove_start_string=length_title_lst.replace(start_string,"")
                                auth_sect=section_abst[len(length_title_lst):start_abst]


                                sect_abs.append(last_index)
                                abst.append(whole_abs)
                                title.append(remove_start_string)
                                #auth.append(title_sect) old wrong way of getting author
                                auth.append(auth_sect)
                                CNS_Year.append(CNS_file[x])
                                last_index
                        # letter + last index up to B1 
                        # section_abst=' '.join(abs_list[abs_beg_ind:abs_end_ind])#entire section including title author and abstract




            else:
                    pass



    print(last_good)
