# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import csv
from bs4 import BeautifulSoup
import urllib
import re
import string
import pandas as pd
import os
import sys
import re

# %%
data = pd.read_csv('../data/CNS_2017_testDC.txt')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-4-4bad1570f79f> in <module>()
# ----> 1 data = pd.read_csv('../data/CNS_2017_testDC.txt')
#
# ...

# %%
pd.read_fwf('../data/CNS_2017_testDC.txt')
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                          Invited Symposium Session 1        NaN        NaN
# 1             FRONTAL CORTEX CONTRIBUTIONS TO DECISION        NaN        NaN
# 2                                               MAKING        NaN        NaN
# 3        Sunday, March 26, 10:00 am - Noon, Ballroom A        NaN        NaN
# 4    Chair: Elisabeth A (Betsy) Murray, National In...        NaN        NaN
# 5                                               Health        NaN        NaN
# 6    Speakers: Betsy Murray, Erin Rich, Paul Cisek,...        NaN        NaN
# 7    There is broad interest in the neural mechanis...    making.        The
# 8    different aspects of decision making in macaqu...        NaN        NaN
# 9    and Rich will unravel the neural substrates an...        NaN        NaN
# 10   underlying object choices in macaque monkeys. ...        NaN        NaN
# ...

# %%
pd.read_csv('../data/CNS_2017_testDC.txt',delimiter="\t")
# Out:
#                            Invited Symposium Session 1
# 0             FRONTAL CORTEX CONTRIBUTIONS TO DECISION
# 1                                               MAKING
# 2        Sunday, March 26, 10:00 am - Noon, Ballroom A
# 3    Chair: Elisabeth A (Betsy) Murray, National In...
# 4                                               Health
# 5    Speakers: Betsy Murray, Erin Rich, Paul Cisek,...
# 6    There is broad interest in the neural mechanis...
# 7    different aspects of decision making in macaqu...
# 8    and Rich will unravel the neural substrates an...
# 9    underlying object choices in macaque monkeys. ...
# 10   the causal contributions of different frontal ...
# 11   choices, focusing on the complementary roles f...
# 12   prefrontal regions. Rich will discuss a novel ...
# 13   representations from orbitofrontal cortex duri...
# 14   high temporal resolution. Cisek will present t...
# 15   decisions about actions unfold as a biased com...
# ...

# %%
file = open('../data/CNS_2017_testDC.txt','r')
data = file.read()
data_list = data.split('Invited Symposium Session 1')
re.split('Invited Symposium Session 1|\n',data)##ideas in Gdoc
# print(data_list.index('\x0cPoster Session A'))
# data_list[data_list.index('\x0cPoster Session H'):]
# Out:
# ['',
#  '',
#  '',
#  'FRONTAL CORTEX CONTRIBUTIONS TO DECISION',
#  'MAKING',
#  'Sunday, March 26, 10:00 am - Noon, Ballroom A',
#  'Chair: Elisabeth A (Betsy) Murray, National Institute of Mental',
#  'Health',
#  'Speakers: Betsy Murray, Erin Rich, Paul Cisek, Joseph Kable',
#  'There is broad interest in the neural mechanisms underlying rewardbased decision making. The four speakers will provide an update on',
#  'different aspects of decision making in macaques and humans. Murray',
#  'and Rich will unravel the neural substrates and neural mechanisms',
#  'underlying object choices in macaque monkeys. Murray will discuss',
#  'the causal contributions of different frontal cortex areas to object',
#  'choices, focusing on the complementary roles for orbital and ventral',
#  'prefrontal regions. Rich will discuss a novel approach to decode value',
#  'representations from orbitofrontal cortex during individual choices with',
# ...

# %%
data
# Out:
# "\nInvited Symposium Session 1\nFRONTAL CORTEX CONTRIBUTIONS TO DECISION\nMAKING\nSunday, March 26, 10:00 am - Noon, Ballroom A\nChair: Elisabeth A (Betsy) Murray, National Institute of Mental\nHealth\nSpeakers: Betsy Murray, Erin Rich, Paul Cisek, Joseph Kable\nThere is broad interest in the neural mechanisms underlying rewardbased decision making. The four speakers will provide an update on\ndifferent aspects of decision making in macaques and humans. Murray\nand Rich will unravel the neural substrates and neural mechanisms\nunderlying object choices in macaque monkeys. Murray will discuss\nthe causal contributions of different frontal cortex areas to object\nchoices, focusing on the complementary roles for orbital and ventral\nprefrontal regions. Rich will discuss a novel approach to decode value\nrepresentations from orbitofrontal cortex during individual choices with\nhigh temporal resolution. Cisek will present the novel hypothesis that\ndecisions about actions unfold as a bias
# ...
